# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("Raw_Housing_Prices3[1].csv")
data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1129575.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.160900e+04  2.160900e+04    21609.000000     21609.000000
# mean   4.580686e+09  5.116186e+05        3.370771         2.114709
# std    2.876653e+09  2.500620e+05        0.929916         0.770097
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904931e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  1.129575e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21609.000000        2.160900e+04  21609.000000   21609.000000
# mean           2079.872553        1.510641e+04      1.494215       7.623490
# std             918.347816        4.142353e+04      0.539909       1.105519
# ...

# %%
sns.catplot(x="Age of House (in Years)",kind="violin",data=data)

# %%
data.shape
# Out:
# (21609, 21)

# %%
data.columns
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
data.head(-10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21594  8956200760     14 October 2017    541800.0               4
# 21595  7202300110   14 September 2017    810000.0               4
# 21596   249000205     14 October 2017   1129575.0               5
# 21597  5100403806       15 April 2016    467000.0               3
# 21598   844000965        14 June 2017    224000.0               3
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data.tail(-100)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 100    5200100125     14 October 2017    555000.0               3
# 101    7214720075    14 December 2017    699950.0               3
# 102    2450000295     14 October 2017   1090000.0               3
# 103    6197800045   14 September 2017    290000.0               3
# 104    1328310370       15 April 2016    375000.0               3
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               3
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 100               2.00               1980.0              3478.0           1.5
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.160900e+04  2.160900e+04    21609.000000     21609.000000
# mean   4.580686e+09  5.116186e+05        3.370771         2.114709
# std    2.876653e+09  2.500620e+05        0.929916         0.770097
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904931e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  1.129575e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21609.000000        2.160900e+04  21609.000000   21609.000000
# mean           2079.872553        1.510641e+04      1.494215       7.623490
# std             918.347816        4.142353e+04      0.539909       1.105519
# ...

# %%
data.describe(include=["object"])
# Out:
#        Date House was Sold Waterfront View No of Times Visited  \
# count                21609           21609               21609
# unique                  13               2                   5
# top          15 April 2016              No                None
# freq                  2231           21446               19485
#
#        Condition of the House
# count                   21609
# unique                      5
# top                      Fair
# freq                    14028

# %%
pd.Series([1,2,3,4,"njfvd"])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4    njfvd
# dtype: object

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
data["Sale Price"][1]
# Out:
# 538000.0

# %%
data.iloc[[1,2],[3,4]]
# Out:
#    No of Bedrooms  No of Bathrooms
# 1               3             2.25
# 2               2             1.00

# %%
data.iloc[0,1]
# Out:
# '14 October 2017'

# %%
data.loc[3]
# Out:
# ID                                                 2487200875
# Date House was Sold                          14 December 2017
# Sale Price                                           604000.0
# No of Bedrooms                                              4
# No of Bathrooms                                           3.0
# Flat Area (in Sqft)                                    1960.0
# Lot Area (in Sqft)                                     5000.0
# No of Floors                                              1.0
# Waterfront View                                            No
# No of Times Visited                                      None
# Condition of the House                              Excellent
# Overall Grade                                               7
# Area of the House from Basement (in Sqft)              1050.0
# Basement Area (in Sqft)                                   910
# Age of House (in Years)                                    53
# ...

# %%
data.loc[[3]]
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 3  2487200875    14 December 2017    604000.0               4
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 3              3.0               1960.0              5000.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 3              No                None  ...             7
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 3                                     1050.0                      910
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 3                       53               0  98136.0   47.5208   -122.393
#
#    Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)
# 3                                  1360.0                                 5000
#
# [1 rows x 21 columns]

# %%
data.loc[:3]
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# 1              No                None  ...             7
# 2              No                None  ...             6
# ...

# %%
data.loc[3,"Date House was Sold"]
# Out:
# '14 December 2017'

# %%
data.loc[2:6,"Waterfront View":"Overall Grade"]
# Out:
#   Waterfront View No of Times Visited Condition of the House  Overall Grade
# 2              No                None                   Fair              6
# 3              No                None              Excellent              7
# 4              No                None                   Fair              8
# 5              No                None                   Fair             10
# 6              No                None                   Fair              7

# %%
pd.set_option("display.max_rows",5)
data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# ...           ...                 ...         ...             ...
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# 1                 2.25               2570.0              7242.0           2.0
# ...                ...                  ...                 ...           ...
# 21607             2.50               1600.0              2388.0           2.0
# 21608             0.75               1020.0              1076.0           2.0
#
#       Waterfront View No of Times Visited  ... Overall Grade  \
# ...

# %%
data.set_index("ID")
# Out:
#            Date House was Sold  Sale Price  No of Bedrooms  No of Bathrooms  \
# ID
# 7129300520     14 October 2017    221900.0               3             1.00
# 6414100192    14 December 2017    538000.0               3             2.25
# ...                        ...         ...             ...              ...
# 291310100      15 January 2016    400000.0               3             2.50
# 1523300157     14 October 2017    325000.0               2             0.75
#
#             Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# ID
# 7129300520               1180.0              5650.0           1.0
# 6414100192               2570.0              7242.0           2.0
# ...                         ...                 ...           ...
# 291310100                1600.0              2388.0           2.0
# 1523300157               1020.0              1076.0           2.0
#
#            Waterfront View No of Times Visited Condition of the House  \
# ID
# ...

# %%
data.set_index("ID","No of Bathrooms")
data.head()
# Out:
# C:\Users\Jaswanth chowdary\AppData\Local\Temp\ipykernel_12560\1009191130.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   data.set_index("ID","No of Bathrooms")
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# ...

# %%
data.reset_index()
# Out:
#        index          ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0          0  7129300520     14 October 2017    221900.0               3
# 1          1  6414100192    14 December 2017    538000.0               3
# ...      ...         ...                 ...         ...             ...
# 21607  21607   291310100     15 January 2016    400000.0               3
# 21608  21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# 1                 2.25               2570.0              7242.0           2.0
# ...                ...                  ...                 ...           ...
# 21607             2.50               1600.0              2388.0           2.0
# 21608             0.75               1020.0              1076.0           2.0
#
#       Waterfront View  ... Overall Grade  \
# ...

# %%
data.reset_index(drop=True)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# ...           ...                 ...         ...             ...
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# 1                 2.25               2570.0              7242.0           2.0
# ...                ...                  ...                 ...           ...
# 21607             2.50               1600.0              2388.0           2.0
# 21608             0.75               1020.0              1076.0           2.0
#
#       Waterfront View No of Times Visited  ... Overall Grade  \
# ...

# %%
data.columns.str.replace(" ","_")
# Out:
# Index(['ID', 'Date_House_was_Sold', 'Sale_Price', 'No_of_Bedrooms',
#        'No_of_Bathrooms', 'Flat_Area_(in_Sqft)', 'Lot_Area_(in_Sqft)',
#        'No_of_Floors', 'Waterfront_View', 'No_of_Times_Visited',
#        'Condition_of_the_House', 'Overall_Grade',
#        'Area_of_the_House_from_Basement_(in_Sqft)', 'Basement_Area_(in_Sqft)',
#        'Age_of_House_(in_Years)', 'Renovated_Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living_Area_after_Renovation_(in_Sqft)',
#        'Lot_Area_after_Renovation_(in_Sqft)'],
#       dtype='object')

# %%
data.columns=[x.lower() for x in data]
data
# Out:
#                id date house was sold  sale price  no of bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# ...           ...                 ...         ...             ...
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        no of bathrooms  flat area (in sqft)  lot area (in sqft)  no of floors  \
# 0                 1.00               1180.0              5650.0           1.0
# 1                 2.25               2570.0              7242.0           2.0
# ...                ...                  ...                 ...           ...
# 21607             2.50               1600.0              2388.0           2.0
# 21608             0.75               1020.0              1076.0           2.0
#
#       waterfront view no of times visited  ... overall grade  \
# ...

# %%
data.rename(columns={"id":"ID"},inplace=True)
data.head()
# Out:
#            ID date house was sold  sale price  no of bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    no of bathrooms  flat area (in sqft)  lot area (in sqft)  no of floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   waterfront view no of times visited  ... overall grade  \
# 0              No                None  ...             7
# ...

# %%
def change(column_manner):
    x=column_manner.lower()
    x=x.replace(" ","_")
    return x

# %%
data["date house was sold"].apply(change).head()
# Out:
# 0     14_october_2017
# 1    14_december_2017
# 2    15_february_2016
# 3    14_december_2017
# 4    15_february_2016
# Name: date house was sold, dtype: object

# %%
data["no of bedrooms"].apply(lambda x:x+5)
# Out:
# 0        8
# 1        8
#         ..
# 21607    8
# 21608    7
# Name: no of bedrooms, Length: 21609, dtype: int64

# %%
data["date house was sold"].apply(len)
# Out:
# 0        15
# 1        16
#          ..
# 21607    15
# 21608    15
# Name: date house was sold, Length: 21609, dtype: int64

# %%
#data.applymap(str.upper)

# %%
data.replace(to_replace=[3],value=4)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               4
# 1      6414100192    14 December 2017    538000.0               4
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               4
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               4
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               4
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
people={
    "First name":["krish","ajhsbc"],
    "Last name":["ksh","sbc"],
    "Mail":["mndvkjdmail","knvjdmail"]
}

# %%
df=pd.DataFrame(people)
df
# Out:
#   First name Last name         Mail
# 0      krish       ksh  mndvkjdmail
# 1     ajhsbc       sbc    knvjdmail

# %%
df.columns=["F name","L name","Gmail"]

# %%
df
# Out:
#    F name L name        Gmail
# 0   krish    ksh  mndvkjdmail
# 1  ajhsbc    sbc    knvjdmail

# %%
df.columns.str.replace(" ","_")
# Out:
# Index(['F_name', 'L_name', 'Gmail'], dtype='object')

# %%
df.columns=[x.lower() for x in df]

# %%
df
# Out:
#    f name l name        gmail
# 0   krish    ksh  mndvkjdmail
# 1  ajhsbc    sbc    knvjdmail

# %%
df.rename(columns={"f name":"FName","l name":"LName"})
# Out:
#     FName LName        gmail
# 0   krish   ksh  mndvkjdmail
# 1  ajhsbc   sbc    knvjdmail

# %%
df.loc[1]=["king","jashu","jashumail"]
df
# Out:
#   f name l name        gmail
# 0  krish    ksh  mndvkjdmail
# 1   king  jashu    jashumail

# %%
df.applymap(str.lower)
# Out:
#   f name l name        gmail
# 0  krish    ksh  mndvkjdmail
# 1   king  jashu    jashumail

# %%
df.replace(to_replace=["mndvkjdmail","jashumail"],value="normal_mail")
# Out:
#   f name l name        gmail
# 0  krish    ksh  normal_mail
# 1   king  jashu  normal_mail

# %%
data["store"]=pd.Series("amazon")
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                None  ...
# 1              No                None  ...
# ...

# %%
df["full name"]=df["f name"]+" "+df["l name"]
df
# Out:
#   f name l name        gmail   full name
# 0  krish    ksh  mndvkjdmail   krish ksh
# 1   king  jashu    jashumail  king jashu

# %%
df["full name"].str.split(" ",expand=True)
# Out:
#        0      1
# 0  krish    ksh
# 1   king  jashu

# %%
df["first"],df["second"]=df["full name"].str.split(" ")
df
# Out:
#   f name l name        gmail   full name  first second
# 0  krish    ksh  mndvkjdmail   krish ksh  krish   king
# 1   king  jashu    jashumail  king jashu    ksh  jashu

# %%
pd.concat([data,df],axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7148\2433952581.py in <module>
# ----> 1 pd.concat([data,df],axis=1,inplace=True).head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got an unexpected keyword argument 'inplace'

# %%
data.drop(columns=["Lot Area (in Sqft)"],axis=1,inplace=False).head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  No of Floors Waterfront View  \
# 0             1.00               1180.0           1.0              No
# 1             2.25               2570.0           2.0              No
# 2             1.00                770.0           1.0              No
# 3             3.00               1960.0           1.0              No
# 4             2.00               1680.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                None                   Fair  ...
# 1                None                   Fair  ...
# ...

# %%
df.append({"gmail":"ncjvd","first":"ncsv","second":"mnbc"},ignore_index=True,sort=True)
# Out:
# C:\Users\Jaswanth chowdary\AppData\Local\Temp\ipykernel_7148\4258943957.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({"gmail":"ncjvd","first":"ncsv","second":"mnbc"},ignore_index=True,sort=True)
#    first        gmail second
# 0  krish  mndvkjdmail   king
# 1    ksh    jashumail  jashu
# 2   ncsv        ncjvd   mnbc

# %%
data.drop(index=[1,2])
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# 5      7237550310         14 May 2017   1129575.0               4
# 6      1321400060        14 June 2017    257500.0               3
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               3
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data.sort_values(by="Date House was Sold").head()
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 11852  9412700160      14 August 2017    255000.0               3
# 6714   9547200460      14 August 2017    640000.0               3
# 16171  8582010290      14 August 2017    683000.0               3
# 6703   4038700380      14 August 2017    657000.0               5
# 16176  5643600351      14 August 2017    257000.0               4
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 11852             2.25               1830.0              7770.0           1.0
# 6714              1.50               1960.0              4080.0           1.5
# 16171             2.50               2300.0              9218.0           2.0
# 6703              2.50               2530.0             10190.0           1.0
# 16176             1.75               1900.0             22896.0           1.5
#
#       Waterfront View No of Times Visited  ...  \
# 11852              No                None  ...
# ...

# %%
data['Sale Price'].nsmallest(10)
# Out:
# 1147     75000.0
# 15291    78000.0
# 463      80000.0
# 16196    81000.0
# 8272     82000.0
# 2139     82500.0
# 18466    83000.0
# 3765     84000.0
# 10251    85000.0
# 16712    85000.0
# Name: Sale Price, dtype: float64

# %%
x=data.groupby(['Date House was Sold'])
x.groups["14 August 2017"]
# Out:
# Int64Index([   21,    41,    56,    58,    61,    68,   108,   134,   135,
#               146,
#             ...
#             21507, 21517, 21530, 21543, 21544, 21550, 21554, 21581, 21592,
#             21599],
#            dtype='int64', length=1940)

# %%
values=[[1,2,3],[2,3,4],[1,None,4],[4,5,6]]
num=pd.DataFrame(values,columns=["a","b","c"])
num
# Out:
#    a    b  c
# 0  1  2.0  3
# 1  2  3.0  4
# 2  1  NaN  4
# 3  4  5.0  6

# %%
grp=num.groupby(by=["b"])
grp.groups
# Out:
# {2.0: [0], 3.0: [1], 5.0: [3]}

# %%
data["No of Bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
data["No of Bedrooms"].value_counts()
# Out:
# 3     9823
# 4     6881
# 2     2759
# 5     1601
# 6      271
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: No of Bedrooms, dtype: int64

# %%
data["No of Bedrooms"].value_counts(normalize=True)
# Out:
# 3     0.454579
# 4     0.318432
# 2     0.127678
# 5     0.074089
# 6     0.012541
# 1     0.009209
# 7     0.001759
# 0     0.000602
# 8     0.000602
# 9     0.000278
# 10    0.000139
# 11    0.000046
# 33    0.000046
# Name: No of Bedrooms, dtype: float64

# %%
d=pd.DataFrame([[1,2,3],[2,3,4],[12,4,5]])

# %%
d.agg(["sum","min","max"])
# Out:
#       0  1   2
# sum  15  9  12
# min   1  2   3
# max  12  4   5

# %%
d.cumsum()
# Out:
#     0  1   2
# 0   1  2   3
# 1   3  5   7
# 2  15  9  12
